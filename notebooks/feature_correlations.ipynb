# %%
import autorootcwd  # noqa
import matplotlib.pyplot as plt

from scripts.utils import load_features

# %%
df = load_features().drop(['user_id', 'product_id'], axis=1)
df.head()
# Out:
#    up_total_orders  up_reorder_ratio  up_last_five  u_dow_mode  u_hod_mode  \
# 0               10          1.000000           5.0           4           7
# 1                9          1.000000           5.0           4           7
# 2                1          0.166667           0.0           4           7
# 3               10          1.000000           5.0           4           7
# 4                3          0.333333           2.0           4           7
#
#    u_total_orders  u_avg_prd  u_reorder_ratio  p_reorder_ratio  \
# 0              10        5.9            0.695         0.776480
# 1              10        5.9            0.695         0.713772
# 2              10        5.9            0.695         0.652009
# 3              10        5.9            0.695         0.740735
# 4              10        5.9            0.695         0.657158
#
#    p_total_orders  p_avg_cart_position
# 0           35791             3.721774
# 1            1946             4.277492
# 2            5526             4.191097
# 3            6476             4.760037
# 4            3751             5.622767

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                      up_total_orders  up_reorder_ratio  up_last_five  \
# up_total_orders             1.000000          0.167805      0.397151
# up_reorder_ratio            0.167805          1.000000      0.663871
# up_last_five                0.397151          0.663871      1.000000
# u_dow_mode                 -0.012640          0.012582      0.004559
# u_hod_mode                 -0.024536          0.023878      0.013229
# u_total_orders              0.236109         -0.414459     -0.288713
# u_avg_prd                   0.052833          0.063162      0.082549
# u_reorder_ratio             0.305886         -0.326640     -0.142332
# p_reorder_ratio             0.232775          0.139662      0.211440
# p_total_orders              0.163532          0.100752      0.160585
# p_avg_cart_position        -0.163560         -0.125764     -0.174363
#
#                      u_dow_mode  u_hod_mode  u_total_orders  u_avg_prd  \
# up_total_orders       -0.012640   -0.024536        0.236109   0.052833
# up_reorder_ratio       0.012582    0.023878       -0.414459   0.063162
# up_last_five           0.004559    0.013229       -0.288713   0.082549
# u_dow_mode             1.000000    0.008318       -0.026329  -0.032382
# u_hod_mode             0.008318    1.000000       -0.062042  -0.006203
# u_total_orders        -0.026329   -0.062042        1.000000  -0.082297
# u_avg_prd             -0.032382   -0.006203       -0.082297   1.000000
# u_reorder_ratio       -0.047323   -0.057148        0.668553   0.162519
# p_reorder_ratio       -0.019877   -0.005363       -0.032801  -0.018562
# p_total_orders        -0.014565    0.002173       -0.033741  -0.022887
# p_avg_cart_position   -0.016028    0.015568        0.065173   0.162592
#
#                      u_reorder_ratio  p_reorder_ratio  p_total_orders  \
# up_total_orders             0.305886         0.232775        0.163532
# up_reorder_ratio           -0.326640         0.139662        0.100752
# up_last_five               -0.142332         0.211440        0.160585
# u_dow_mode                 -0.047323        -0.019877       -0.014565
# u_hod_mode                 -0.057148        -0.005363        0.002173
# u_total_orders              0.668553        -0.032801       -0.033741
# u_avg_prd                   0.162519        -0.018562       -0.022887
# u_reorder_ratio             1.000000         0.037576       -0.001281
# p_reorder_ratio             0.037576         1.000000        0.419777
# p_total_orders             -0.001281         0.419777        1.000000
# p_avg_cart_position         0.029515        -0.523129       -0.334479
#
#                      p_avg_cart_position
# up_total_orders                -0.163560
# up_reorder_ratio               -0.125764
# up_last_five                   -0.174363
# u_dow_mode                     -0.016028
# u_hod_mode                      0.015568
# u_total_orders                  0.065173
# u_avg_prd                       0.162592
# u_reorder_ratio                 0.029515
# p_reorder_ratio                -0.523129
# p_total_orders                 -0.334479
# p_avg_cart_position             1.000000

# %%
# Plot the heatmap
plt.figure(figsize=(8, 6))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar(label='Correlation Coefficient')

# Add labels
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)

# Title and layout adjustments
plt.title('Correlation Matrix')
plt.tight_layout()

# Show the plot
plt.show()
